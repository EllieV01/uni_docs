# %% [markdown]
# <a href="https://colab.research.google.com/github/EllieV01/uni_docs/blob/main/Cars_copy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Setup
#
# Clone repo, install dependencies and check PyTorch and GPU.

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install

import torch
from yolov5 import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-34-g1ae9194 Python-3.8.16 torch-1.13.0+cu116 CUDA:0 (Tesla T4, 15110MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 23.3/78.2 GB disk)

# %%
# !unzip -q ../train_data.zip -d ../

# %% [markdown]
# # Inference

# %%
import time 
import signal

while True:
  signal.alarm(2) 
  # !python detect.py --weights runs/train/exp3/weights/best.pt --img 640 --conf 0.6 --iou 0.20  --name result_detect --save-txt --source ../video.mp4
  signal.alarm(0)
  time.sleep(2)

# %%
# !python detect.py --weights runs/train/exp/weights/best.pt --img 640 --conf 0.6 --iou 0.20  --name result_detect --save-txt --source ../video.mp4
# Out:
# detect: weights=['runs/train/exp/weights/best.pt'], source=../video.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.6, iou_thres=0.2, max_det=1000, device=, view_img=False, save_txt=True, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=result_detect, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-186-gb3eaf50 torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/939) /content/video.mp4: 384x640 18 cars, Done. (0.027s)
# video 1/1 (2/939) /content/video.mp4: 384x640 18 cars, Done. (0.027s)
# video 1/1 (3/939) /content/video.mp4: 384x640 17 cars, Done. (0.027s)
# video 1/1 (4/939) /content/video.mp4: 384x640 18 cars, Done. (0.030s)
# video 1/1 (5/939) /content/video.mp4: 384x640 18 cars, Done. (0.032s)
# ...

# %% [markdown]
# # Train

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# Train YOLOv5s on COCO128 for 3 epochs
# !python train.py --img 640 --batch 2 --epochs 60 --data custom_data.yaml --weights yolov5s.pt --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=custom_data.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=60, batch_size=2, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.0-186-gb3eaf50 torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# ...
